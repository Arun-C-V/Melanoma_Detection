# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
# !pip install tensorflow
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from glob import glob

# %%
print("TensorFlow version:", tf.__version__)
# !pip install tensorflow==2.13.0
# Out:
# TensorFlow version: 2.13.0
# Collecting tensorflow==2.13.0
#   Obtaining dependency information for tensorflow==2.13.0 from https://files.pythonhosted.org/packages/9e/b8/ed5f794359d05cd0bffb894c6418da87b93016ee17b669d55c45d1bd5d5b/tensorflow-2.13.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow-2.13.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.64.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.32.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.2.2)
# Using cached tensorflow-2.13.0-cp311-cp311-win_amd64.whl (1.9 kB)
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.2
#     Uninstalling tensorflow-2.16.2:
#       Successfully uninstalled tensorflow-2.16.2
# Successfully installed tensorflow-2.13.0

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train")
data_dir_test = pathlib.Path('CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Test')

# %%
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Writing train dataset here

train_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='training',
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here

val_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='validation',
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### create a code to visualize one instance of all the nine classes present in the dataset

# %%
### Using training or validation data to visualize
import matplotlib.pyplot as plt
for i in range(len(class_names)):
    filtered_ds = train_ds.filter(lambda x, l: tf.math.equal(l[0], i))
    for image, label in filtered_ds.take(1):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(class_names[label.numpy()[i]])
        plt.axis('off')

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
##The Keras sequence class helps create a layer cluster that is linearly stacked into a tf. keras. Model.
num_class = 9
model = tf.keras.Sequential([
    layers.Rescaling(scale = 1./255, input_shape = (180,180,3)),
    layers.Conv2D(16,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),    
    layers.Conv2D(32,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),
    layers.Conv2D(64,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dense(num_class)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Choosing an appropirate optimiser and loss function
#loss: Sparse Categorical Crossentropy Calculates the crossentropy loss between labels and predictions.
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 90s 1s/step - loss: 2.1291 - accuracy: 0.2349 - val_loss: 1.8638 - val_accuracy: 0.3065
# Epoch 2/20
# 56/56 [==============================] - 58s 1s/step - loss: 1.7743 - accuracy: 0.3465 - val_loss: 1.6634 - val_accuracy: 0.3893
# Epoch 3/20
# 56/56 [==============================] - 79s 1s/step - loss: 1.6758 - accuracy: 0.4107 - val_loss: 1.6532 - val_accuracy: 0.3870
# Epoch 4/20
# 56/56 [==============================] - 78s 1s/step - loss: 1.5319 - accuracy: 0.4576 - val_loss: 1.7258 - val_accuracy: 0.3826
# Epoch 5/20
# 56/56 [==============================] - 69s 1s/step - loss: 1.4325 - accuracy: 0.5173 - val_loss: 1.4957 - val_accuracy: 0.5034
# Epoch 6/20
# 56/56 [==============================] - 81s 1s/step - loss: 1.3114 - accuracy: 0.5474 - val_loss: 1.3417 - val_accuracy: 0.5391
# Epoch 7/20
# 56/56 [==============================] - 61s 1s/step - loss: 1.2175 - accuracy: 0.5765 - val_loss: 1.4019 - val_accuracy: 0.5168
# Epoch 8/20
# 56/56 [==============================] - 61s 1s/step - loss: 1.1595 - accuracy: 0.5971 - val_loss: 1.4194 - val_accuracy: 0.5011
# Epoch 9/20
# 56/56 [==============================] - 56s 1s/step - loss: 1.1082 - accuracy: 0.6099 - val_loss: 1.5298 - val_accuracy: 0.4787
# Epoch 10/20
# 56/56 [==============================] - 62s 1s/step - loss: 0.9665 - accuracy: 0.6568 - val_loss: 1.5103 - val_accuracy: 0.5257
# Epoch 11/20
# 56/56 [==============================] - 77s 1s/step - loss: 0.9086 - accuracy: 0.6691 - val_loss: 1.5859 - val_accuracy: 0.5190
# Epoch 12/20
# 56/56 [==============================] - 67s 1s/step - loss: 0.8057 - accuracy: 0.6987 - val_loss: 1.6130 - val_accuracy: 0.5436
# Epoch 13/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.7840 - accuracy: 0.7182 - val_loss: 1.6542 - val_accuracy: 0.5235
# Epoch 14/20
# 56/56 [==============================] - 66s 1s/step - loss: 0.6808 - accuracy: 0.7506 - val_loss: 1.8387 - val_accuracy: 0.4720
# Epoch 15/20
# 56/56 [==============================] - 62s 1s/step - loss: 0.6136 - accuracy: 0.7807 - val_loss: 1.8673 - val_accuracy: 0.4966
# Epoch 16/20
# 56/56 [==============================] - 58s 1s/step - loss: 0.5905 - accuracy: 0.7907 - val_loss: 1.9585 - val_accuracy: 0.4944
# Epoch 17/20
# 56/56 [==============================] - 58s 1s/step - loss: 0.5006 - accuracy: 0.8170 - val_loss: 2.0304 - val_accuracy: 0.5034
# Epoch 18/20
# 56/56 [==============================] - 68s 1s/step - loss: 0.4699 - accuracy: 0.8371 - val_loss: 2.0749 - val_accuracy: 0.5213
# Epoch 19/20
# 56/56 [==============================] - 68s 1s/step - loss: 0.4227 - accuracy: 0.8421 - val_loss: 2.1357 - val_accuracy: 0.5145
# Epoch 20/20
# 56/56 [==============================] - 57s 1s/step - loss: 0.3714 - accuracy: 0.8594 - val_loss: 2.2370 - val_accuracy: 0.5324

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Findings:
# <h2>Findings:-</h2>
# <p style="font-size:18px"> The above model is clearly the case of overfitting and the model doesn't seem to be learning anything from the dataset. <br/>
#    &nbsp;&nbsp; (1) Training accuracy is very high, while validation accuracy is around 50%. <br/>
#    &nbsp;&nbsp; (2) The loss on the training set decreases after each epoch, but in the case of the validation set, it climbs back again after the 5th epoch. <br/>
#     <br/>
# Instead of generalizing and learning real features and general relationships, the model memorized the data</p>

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(height_factor=(0.2,0.3), width_factor=(0.2,0.3))  
])

# %%
#Visualize how your augmentation strategy works for one instance of training image.
for img, labels in train_ds.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(data_augmentation(img)[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## Use Dropout layer if there is an evidence of overfitting in your findings
## https://www.tensorflow.org/tutorials/images/data_augmentation
## https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/RandomFlip
## Your code goes here
#The Keras sequence class helps create a layer cluster that is linearly stacked into a tf. keras. Model.

num_classes = 9
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
##Note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
) ## your training code
# Out:
# Epoch 1/20
# 56/56 [==============================] - 77s 1s/step - loss: 2.0506 - accuracy: 0.2294 - val_loss: 2.0281 - val_accuracy: 0.2237
# Epoch 2/20
# 56/56 [==============================] - 72s 1s/step - loss: 1.8525 - accuracy: 0.3125 - val_loss: 1.7393 - val_accuracy: 0.3512
# Epoch 3/20
# 56/56 [==============================] - 75s 1s/step - loss: 1.7109 - accuracy: 0.3906 - val_loss: 1.6408 - val_accuracy: 0.4049
# Epoch 4/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.6464 - accuracy: 0.4074 - val_loss: 1.5451 - val_accuracy: 0.4564
# Epoch 5/20
# 56/56 [==============================] - 57s 1s/step - loss: 1.5762 - accuracy: 0.4336 - val_loss: 1.5628 - val_accuracy: 0.4295
# Epoch 6/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.4992 - accuracy: 0.4665 - val_loss: 1.4468 - val_accuracy: 0.5056
# Epoch 7/20
# 56/56 [==============================] - 55s 974ms/step - loss: 1.4258 - accuracy: 0.4955 - val_loss: 1.3893 - val_accuracy: 0.5213
# Epoch 8/20
# 56/56 [==============================] - 54s 971ms/step - loss: 1.4233 - accuracy: 0.4972 - val_loss: 1.4750 - val_accuracy: 0.4676
# Epoch 9/20
# 56/56 [==============================] - 61s 1s/step - loss: 1.3932 - accuracy: 0.5000 - val_loss: 1.3507 - val_accuracy: 0.5123
# Epoch 10/20
# 56/56 [==============================] - 61s 1s/step - loss: 1.3515 - accuracy: 0.5084 - val_loss: 1.4400 - val_accuracy: 0.4877
# Epoch 11/20
# 56/56 [==============================] - 56s 1s/step - loss: 1.3299 - accuracy: 0.5156 - val_loss: 1.3414 - val_accuracy: 0.5257
# Epoch 12/20
# 56/56 [==============================] - 54s 959ms/step - loss: 1.2740 - accuracy: 0.5374 - val_loss: 1.3183 - val_accuracy: 0.5145
# Epoch 13/20
# 56/56 [==============================] - 51s 907ms/step - loss: 1.2787 - accuracy: 0.5469 - val_loss: 1.4020 - val_accuracy: 0.4922
# Epoch 14/20
# 56/56 [==============================] - 64s 1s/step - loss: 1.2381 - accuracy: 0.5614 - val_loss: 1.4287 - val_accuracy: 0.4922
# Epoch 15/20
# 56/56 [==============================] - 59s 1s/step - loss: 1.2715 - accuracy: 0.5352 - val_loss: 1.3536 - val_accuracy: 0.5145
# Epoch 16/20
# 56/56 [==============================] - 58s 1s/step - loss: 1.2277 - accuracy: 0.5541 - val_loss: 1.4237 - val_accuracy: 0.5280
# Epoch 17/20
# 56/56 [==============================] - 55s 977ms/step - loss: 1.2240 - accuracy: 0.5586 - val_loss: 1.3111 - val_accuracy: 0.5280
# Epoch 18/20
# 56/56 [==============================] - 53s 947ms/step - loss: 1.1793 - accuracy: 0.5748 - val_loss: 1.4011 - val_accuracy: 0.5213
# Epoch 19/20
# 56/56 [==============================] - 52s 922ms/step - loss: 1.2343 - accuracy: 0.5536 - val_loss: 1.4223 - val_accuracy: 0.4944
# Epoch 20/20
# 56/56 [==============================] - 54s 963ms/step - loss: 1.2113 - accuracy: 0.5653 - val_loss: 1.3328 - val_accuracy: 0.5347

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
# <h2>Findings:-</h2>
# <p style="font-size:18px"> In the above model use of data augmentation and dropout layer reduced the problem of overfitting. <br/>
#     <br/>The accuracy of the model has greatly increased along with the synchronization of the verification accuracy. The loss function is synchronously exhausted for the training and validation data.</p>

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## original_df - > path_list, lesion_list
path_list=[]
lesion_list=[]

# %%
for i in class_names:
  for j in data_dir_train.glob(i+'/*.jpg'):
    path_list.append(str(j))
    lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns=['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 1     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 2     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 3     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 4     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# ...                                                 ...                ...
# 2234  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2235  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2236  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2237  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2238  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
# glob('./Skin cancer ISIC The International Skin Imaging Collaboration/train/*/*')
# './Skin cancer ISIC The International Skin Imaging Collaboration/train\\actinic keratosis\\ISIC_0025780.jpg'
class_count=[]
for i in class_names:
    class_count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,class_count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Findings:
# #### - Which class has the least number of samples?
# <p syle="size:18px">The least number of samples are in seborrheic keratosis</p>
#
# #### - Which classes dominate the data in terms proportionate number of samples?
# <p syle="size:18px">The classes dominate in the data are:-
# <br/> * pigmented benign
# <br/> * melanoma
# <br/>* basal cell carcinoma
# <br/>* nevus</p>

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from Augmentor) (1.24.3)
# Requirement already satisfied: colorama in c:\users\arun.cv\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.6)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability = 0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
    
    ## Note: getting an error due to local file issues. Code is working while running at other iterations.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1DB06ED7E50>: 100%|█| 500/500 [00:06<00:00, 79.25 Samples/
# Initialised with 376 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1DB06EB2490>: 100%|█| 500/500 [00:06<00:00, 71.89 Samples/
# Initialised with 95 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1DB09C132D0>: 100%|█| 500/500 [00:07<00:00, 63.32 Samples/
# Initialised with 438 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x1DB22CA2A50>: 100%|█| 500/500 [00:44<00:00, 11.28 Samples
# Initialised with 357 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3072x2304 at 0x1DB06FD1190>: 100%|█| 500/500 [00:39<0
# Initialised with 462 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis\output.
# Executing Pipeline:   0%|                                                                | 0/500 [00:00<?, ? Samples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\Augmentor\Pipeline.py:251, in Pipeline._execute(self, augmentor_image, save_to_disk, multi_threaded)
#     243     save_name = augmentor_image.class_label \
#     244                 + "_original_" \
#     245                 + os.path.basename(augmentor_image.image_path) \
#    (...)
#     248                 + "." \
#     249                 + (self.save_format if self.save_format else augmentor_image.file_format)
# --> 251     images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     253 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\PIL\Image.py:2428, in Image.save(self, fp, format, **params)
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\arun.cv\\Documents\\GenAI\\Projects\\Melanoma_Detection\\CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\pigmented benign keratosis\\output\\pigmented benign keratosis_original_ISIC_0025063.jpg_ee7c1f53-4117-4619-9775-2f7ea9697066.jpg'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 6
#       4 p = Augmentor.Pipeline(path_to_training_dataset + i)
#       5 p.rotate(probability = 0.7, max_left_rotation=10, max_right_rotation=10)
# ----> 6 p.sample(500)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\Augmentor\Pipeline.py:364, in Pipeline.sample(self, n, multi_threaded)
#     362 with tqdm(total=len(augmentor_images), desc="Executing Pipeline", unit=" Samples") as progress_bar:
#     363     with ThreadPoolExecutor(max_workers=None) as executor:
# --> 364         for result in executor.map(self, augmentor_images):
#     365             progress_bar.set_description("Processing %s" % result)
#     366             progress_bar.update(1)
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\Augmentor\Pipeline.py:105, in Pipeline.__call__(self, augmentor_image)
#      92 def __call__(self, augmentor_image):
#      93     """
#      94     Function used by the ThreadPoolExecutor to process the pipeline
#      95     using multiple threads. Do not call directly.
#    (...)
#     103     :return: None
#     104     """
# --> 105     return self._execute(augmentor_image)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\Augmentor\Pipeline.py:268, in Pipeline._execute(self, augmentor_image, save_to_disk, multi_threaded)
#     265             images[i].save(os.path.join(augmentor_image.output_directory, save_name))
#     267 except IOError as e:
# --> 268     print("Error writing %s, %s. Change save_format to PNG?" % (file_name, e.message))
#     269     print("You can change the save format using the set_save_format(save_format) function.")
#     270     print("By passing save_format=\"auto\", Augmentor can save in the correct format automatically.")
#
# AttributeError: 'FileNotFoundError' object has no attribute 'message'

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 5000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_1133e1f6-bdef-4b20-a4a4-1072e5f3e06c.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_25603f35-c2d4-478a-a83e-ea2010b0e47a.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_4818ae70-9e8a-4770-9a2c-e64b040d76ae.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_83a5a34e-6455-4dc0-9e15-258f0db58503.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_94183033-fa7c-4ee3-9021-903862f55917.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_bacd6986-8e46-405c-bc40-f1b13b0275ff.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_bc99bef1-ff75-4283-9e42-543318028dd8.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg
.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_1f0991e8-38d9-4fdb-85e8-a2d40809b49a.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_3adb6eb1-a369-4d20-85c7-2936cf1a5c9a.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_66dddb63-0bae-4581-b633-55918aff1011.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_774a1c7b-ca5a-4ed4-a1df-e0d07bc33be1.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_88dd173e-c710-43f1-9d4a-1ca1899a53db.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_9b396bbd-d3f7-48d2-bdca-7815f8797cdc.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_a504ad79-4565-454c-941d-bc1e3887bea0.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_af01ef36-2e9f-4246-9bfc-7cfa7defa74d.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_b29e1325-ffed-4b18-9e94-ecf0119207a0.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_cd2c2146-9751-42eb-993b-113ba888bd15.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_cf4add97-4b0c-4079-accb-57478fff3cf4.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_e7d2d43a-a5f5-4028-a9ef-b354f282d04b.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_12ffc492-9a4b-44ad-b1fd-322b180acc3f.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_6c69c252-f6c8-4f92-8a9b-bb4fdcd1ba81.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_85f45316-0cad-4b05-98c0-d358432619da.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_b28aa15a-444d-41fb-9d7a-dccb5b5d0a5b.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_cb199c26-2078-40ee-86ee-4721c4d42ce0.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_d77a0588-6c90-470d-9392-28896b65a1b2.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_0cfa3fc3-7bf4-4219-91b4-d464ff993492.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_332e2225-30a3-427d-90b8-8c21ecd76efe.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_56a07ef5-c9ec-4609-9ba4-1f440772279c.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_5f839579-a78f-4813-acb9-6d566675a584.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_629371bb-72a7-44ed-9178-54ec9286930c.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_9d8e4dd2-4278-4b6c-8f9c-d609aadab6ef.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_ed7eeaaa-59f7-4ad4-89a2-e28ea7b4bc21.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_f941e461-2b4d-4f98-b077-d1a85bf31d35.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_3b318be4-c406-4ddd-a8b7-3b2690acf6d2.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_67f44303-209f-4f25-a853-ee2915485dcf.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_69c5647e-fce8-47e8-a4a3-82f0764172d7.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_da1be512-41ab-4ecb-ba73-9f09df4e8e6e.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_e230ca36-4906-4934-8722-c3889fd9d10b.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_e785abed-b890-478c-ba53-1b5b8a47f2ad.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_e916e519-66fb-427e-990e-54ba91f6c6b4.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_ea85b00b-b1c3-4ae8-be0e-fc95095f9b72.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  ...]

# %%
# 'train/class_name/output/221tews.jpg'.split('/')[-3]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = pd.concat([original_df,df2])

# %%
new_df['Label'].value_counts()
# Out:
# Label
# melanoma                      1438
# basal cell carcinoma          1376
# nevus                         1357
# actinic keratosis             1114
# dermatofibroma                1095
# pigmented benign keratosis     462
# squamous cell carcinoma        181
# vascular lesion                139
# seborrheic keratosis            77
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
                                  data_dir_train,
                                  seed=123,
                                  validation_split = 0.2,
                                  subset = 'training',## Todo choose the correct parameter value, so that only training data is refered to,,
                                  image_size=(img_height, img_width),
                                  batch_size=batch_size)
# Out:
# Found 7239 files belonging to 9 classes.
# Using 5792 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
                                  data_dir_train,
                                  seed=123,
                                  validation_split = 0.2,
                                  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
                                  image_size=(img_height, img_width),
                                  batch_size=batch_size)
# Out:
# Found 7239 files belonging to 9 classes.
# Using 1447 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
num_classes = 9
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history30 = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)# your model fit code
# Out:
# Epoch 1/30
# 181/181 [==============================] - 218s 1s/step - loss: 1.6753 - accuracy: 0.3577 - val_loss: 1.4662 - val_accuracy: 0.4561
# Epoch 2/30
# 181/181 [==============================] - 177s 974ms/step - loss: 1.4579 - accuracy: 0.4548 - val_loss: 1.5945 - val_accuracy: 0.4540
# Epoch 3/30
# 181/181 [==============================] - 187s 1s/step - loss: 1.4036 - accuracy: 0.4888 - val_loss: 1.4075 - val_accuracy: 0.4748
# Epoch 4/30
# 181/181 [==============================] - 178s 980ms/step - loss: 1.3597 - accuracy: 0.4981 - val_loss: 1.3159 - val_accuracy: 0.5225
# Epoch 5/30
# 181/181 [==============================] - 187s 1s/step - loss: 1.3353 - accuracy: 0.5105 - val_loss: 1.2740 - val_accuracy: 0.5273
# Epoch 6/30
# 181/181 [==============================] - 184s 1s/step - loss: 1.2790 - accuracy: 0.5394 - val_loss: 1.2585 - val_accuracy: 0.5404
# Epoch 7/30
# 181/181 [==============================] - 195s 1s/step - loss: 1.2358 - accuracy: 0.5622 - val_loss: 1.2061 - val_accuracy: 0.5612
# Epoch 8/30
# 181/181 [==============================] - 222s 1s/step - loss: 1.1846 - accuracy: 0.5770 - val_loss: 1.1576 - val_accuracy: 0.5826
# Epoch 9/30
# 181/181 [==============================] - 199s 1s/step - loss: 1.1805 - accuracy: 0.5773 - val_loss: 1.1729 - val_accuracy: 0.5833
# Epoch 10/30
# 181/181 [==============================] - 181s 994ms/step - loss: 1.1375 - accuracy: 0.5994 - val_loss: 1.1812 - val_accuracy: 0.5715
# Epoch 11/30
# 181/181 [==============================] - 192s 1s/step - loss: 1.0859 - accuracy: 0.6095 - val_loss: 1.1030 - val_accuracy: 0.5985
# Epoch 12/30
# 181/181 [==============================] - 213s 1s/step - loss: 1.0635 - accuracy: 0.6257 - val_loss: 1.1005 - val_accuracy: 0.6123
# Epoch 13/30
# 181/181 [==============================] - 247s 1s/step - loss: 1.0671 - accuracy: 0.6291 - val_loss: 1.1233 - val_accuracy: 0.5971
# Epoch 14/30
# 181/181 [==============================] - 214s 1s/step - loss: 1.0193 - accuracy: 0.6402 - val_loss: 1.0851 - val_accuracy: 0.6247
# Epoch 15/30
# 181/181 [==============================] - 328s 2s/step - loss: 1.0181 - accuracy: 0.6436 - val_loss: 1.0600 - val_accuracy: 0.6220
# Epoch 16/30
# 181/181 [==============================] - 246s 1s/step - loss: 0.9535 - accuracy: 0.6683 - val_loss: 0.9465 - val_accuracy: 0.6704
# Epoch 17/30
# 181/181 [==============================] - 207s 1s/step - loss: 0.9294 - accuracy: 0.6801 - val_loss: 0.9721 - val_accuracy: 0.6496
# Epoch 18/30
# 181/181 [==============================] - 213s 1s/step - loss: 0.9533 - accuracy: 0.6685 - val_loss: 0.9681 - val_accuracy: 0.6593
# Epoch 19/30
# 181/181 [==============================] - 291s 2s/step - loss: 0.9227 - accuracy: 0.6775 - val_loss: 0.9728 - val_accuracy: 0.6731
# Epoch 20/30
# 181/181 [==============================] - 228s 1s/step - loss: 0.8712 - accuracy: 0.6998 - val_loss: 1.0144 - val_accuracy: 0.6434
# Epoch 21/30
# 181/181 [==============================] - 238s 1s/step - loss: 0.8513 - accuracy: 0.7051 - val_loss: 0.9153 - val_accuracy: 0.6842
# Epoch 22/30
# 181/181 [==============================] - 204s 1s/step - loss: 0.8423 - accuracy: 0.7049 - val_loss: 0.8923 - val_accuracy: 0.6786
# Epoch 23/30
# 181/181 [==============================] - 188s 1s/step - loss: 0.8094 - accuracy: 0.7181 - val_loss: 0.8534 - val_accuracy: 0.6869
# Epoch 24/30
# 181/181 [==============================] - 188s 1s/step - loss: 0.8308 - accuracy: 0.7094 - val_loss: 0.8490 - val_accuracy: 0.7104
# Epoch 25/30
# 181/181 [==============================] - 193s 1s/step - loss: 0.7945 - accuracy: 0.7217 - val_loss: 0.8642 - val_accuracy: 0.7070
# Epoch 26/30
# 181/181 [==============================] - 205s 1s/step - loss: 0.7889 - accuracy: 0.7274 - val_loss: 0.8957 - val_accuracy: 0.6952
# Epoch 27/30
# 181/181 [==============================] - 190s 1s/step - loss: 0.7705 - accuracy: 0.7376 - val_loss: 0.9039 - val_accuracy: 0.6932
# Epoch 28/30
# 181/181 [==============================] - 233s 1s/step - loss: 0.7503 - accuracy: 0.7443 - val_loss: 0.9277 - val_accuracy: 0.6842
# Epoch 29/30
# 181/181 [==============================] - 218s 1s/step - loss: 0.7317 - accuracy: 0.7402 - val_loss: 0.8837 - val_accuracy: 0.7097
# Epoch 30/30
# 181/181 [==============================] - 242s 1s/step - loss: 0.7496 - accuracy: 0.7369 - val_loss: 0.8882 - val_accuracy: 0.7077

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# The problem of overfitting and underfitting was solved and the model was well trained for predictions. Data augmentation, outliers, and class equalization were found to be useful in improving model performance in this case.

# %% [markdown]
# #### Train your model for 20 more epochs

# %%
epochs = 20
## Your code goes here, use 30 epochs.
history20 = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)# your model fit code
# Out:
# Epoch 1/20
# 181/181 [==============================] - 252s 1s/step - loss: 0.7072 - accuracy: 0.7545 - val_loss: 0.9315 - val_accuracy: 0.7008
# Epoch 2/20
# 181/181 [==============================] - 221s 1s/step - loss: 0.7177 - accuracy: 0.7436 - val_loss: 0.8324 - val_accuracy: 0.7153
# Epoch 3/20
# 181/181 [==============================] - 208s 1s/step - loss: 0.7032 - accuracy: 0.7564 - val_loss: 0.8570 - val_accuracy: 0.7146
# Epoch 4/20
# 181/181 [==============================] - 204s 1s/step - loss: 0.7025 - accuracy: 0.7579 - val_loss: 0.7869 - val_accuracy: 0.7367
# Epoch 5/20
# 181/181 [==============================] - 200s 1s/step - loss: 0.6795 - accuracy: 0.7616 - val_loss: 0.9305 - val_accuracy: 0.6932
# Epoch 6/20
# 181/181 [==============================] - 233s 1s/step - loss: 0.6737 - accuracy: 0.7631 - val_loss: 0.8460 - val_accuracy: 0.7160
# Epoch 7/20
# 181/181 [==============================] - 212s 1s/step - loss: 0.6620 - accuracy: 0.7778 - val_loss: 0.8422 - val_accuracy: 0.7160
# Epoch 8/20
# 181/181 [==============================] - 215s 1s/step - loss: 0.6579 - accuracy: 0.7740 - val_loss: 0.8811 - val_accuracy: 0.7139
# Epoch 9/20
# 181/181 [==============================] - 214s 1s/step - loss: 0.6238 - accuracy: 0.7764 - val_loss: 0.8277 - val_accuracy: 0.7388
# Epoch 10/20
# 181/181 [==============================] - 225s 1s/step - loss: 0.6386 - accuracy: 0.7818 - val_loss: 0.9498 - val_accuracy: 0.7021
# Epoch 11/20
# 181/181 [==============================] - 254s 1s/step - loss: 0.6465 - accuracy: 0.7788 - val_loss: 0.8310 - val_accuracy: 0.7256
# Epoch 12/20
# 181/181 [==============================] - 269s 1s/step - loss: 0.6363 - accuracy: 0.7764 - val_loss: 0.9679 - val_accuracy: 0.6828
# Epoch 13/20
# 181/181 [==============================] - 244s 1s/step - loss: 0.6228 - accuracy: 0.7825 - val_loss: 0.8002 - val_accuracy: 0.7395
# Epoch 14/20
# 181/181 [==============================] - 261s 1s/step - loss: 0.6364 - accuracy: 0.7842 - val_loss: 0.8921 - val_accuracy: 0.7063
# Epoch 15/20
# 181/181 [==============================] - 234s 1s/step - loss: 0.5965 - accuracy: 0.7971 - val_loss: 0.7688 - val_accuracy: 0.7609
# Epoch 16/20
# 181/181 [==============================] - 220s 1s/step - loss: 0.6160 - accuracy: 0.7866 - val_loss: 0.8010 - val_accuracy: 0.7491
# Epoch 17/20
# 181/181 [==============================] - 228s 1s/step - loss: 0.5982 - accuracy: 0.7928 - val_loss: 0.8050 - val_accuracy: 0.7415
# Epoch 18/20
# 181/181 [==============================] - 264s 1s/step - loss: 0.5771 - accuracy: 0.8054 - val_loss: 0.9631 - val_accuracy: 0.7008
# Epoch 19/20
# 181/181 [==============================] - 270s 1s/step - loss: 0.5863 - accuracy: 0.7958 - val_loss: 0.8344 - val_accuracy: 0.7464
# Epoch 20/20
# 181/181 [==============================] - 271s 1s/step - loss: 0.6106 - accuracy: 0.7873 - val_loss: 0.8428 - val_accuracy: 0.7388

# %% [markdown]
# #### Visualize the model results for 20 more epochs

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Train your model for 50 more epochs

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)# your model fit code
# Out:
# Epoch 1/50
# 181/181 [==============================] - 262s 1s/step - loss: 0.5810 - accuracy: 0.8030 - val_loss: 0.8492 - val_accuracy: 0.7298
# Epoch 2/50
# 181/181 [==============================] - 262s 1s/step - loss: 0.5901 - accuracy: 0.8002 - val_loss: 0.8790 - val_accuracy: 0.7146
# Epoch 3/50
# 181/181 [==============================] - 256s 1s/step - loss: 0.5695 - accuracy: 0.8046 - val_loss: 0.8361 - val_accuracy: 0.7422
# Epoch 4/50
# 181/181 [==============================] - 255s 1s/step - loss: 0.5430 - accuracy: 0.8120 - val_loss: 0.8633 - val_accuracy: 0.7270
# Epoch 5/50
# 181/181 [==============================] - 249s 1s/step - loss: 0.6117 - accuracy: 0.7894 - val_loss: 0.8743 - val_accuracy: 0.7111
# Epoch 6/50
# 181/181 [==============================] - 243s 1s/step - loss: 0.5711 - accuracy: 0.8002 - val_loss: 0.8210 - val_accuracy: 0.7471
# Epoch 7/50
# 181/181 [==============================] - 223s 1s/step - loss: 0.5483 - accuracy: 0.8111 - val_loss: 0.8216 - val_accuracy: 0.7519
# Epoch 8/50
# 181/181 [==============================] - 251s 1s/step - loss: 0.5433 - accuracy: 0.8137 - val_loss: 0.9214 - val_accuracy: 0.7319
# Epoch 9/50
# 181/181 [==============================] - 232s 1s/step - loss: 0.5709 - accuracy: 0.8016 - val_loss: 0.8985 - val_accuracy: 0.7208
# Epoch 10/50
# 181/181 [==============================] - 240s 1s/step - loss: 0.5363 - accuracy: 0.8166 - val_loss: 0.8281 - val_accuracy: 0.7616
# Epoch 11/50
# 181/181 [==============================] - 221s 1s/step - loss: 0.5414 - accuracy: 0.8149 - val_loss: 0.8390 - val_accuracy: 0.7685
# Epoch 12/50
# 181/181 [==============================] - 236s 1s/step - loss: 0.5226 - accuracy: 0.8204 - val_loss: 0.8299 - val_accuracy: 0.7436
# Epoch 13/50
# 181/181 [==============================] - 220s 1s/step - loss: 0.5109 - accuracy: 0.8253 - val_loss: 0.8879 - val_accuracy: 0.7298
# Epoch 14/50
# 181/181 [==============================] - 244s 1s/step - loss: 0.5596 - accuracy: 0.8032 - val_loss: 0.8081 - val_accuracy: 0.7754
# Epoch 15/50
# 181/181 [==============================] - 257s 1s/step - loss: 0.5281 - accuracy: 0.8198 - val_loss: 0.8524 - val_accuracy: 0.7388
# Epoch 16/50
# 181/181 [==============================] - 229s 1s/step - loss: 0.5298 - accuracy: 0.8139 - val_loss: 0.8370 - val_accuracy: 0.7491
# Epoch 17/50
# 181/181 [==============================] - 243s 1s/step - loss: 0.5351 - accuracy: 0.8168 - val_loss: 1.2133 - val_accuracy: 0.6704
# Epoch 18/50
# 181/181 [==============================] - 247s 1s/step - loss: 0.5038 - accuracy: 0.8268 - val_loss: 0.8236 - val_accuracy: 0.7602
# Epoch 19/50
# 181/181 [==============================] - 260s 1s/step - loss: 0.5243 - accuracy: 0.8168 - val_loss: 0.8145 - val_accuracy: 0.7664
# Epoch 20/50
# 181/181 [==============================] - 273s 2s/step - loss: 0.5103 - accuracy: 0.8256 - val_loss: 0.8309 - val_accuracy: 0.7630
# Epoch 21/50
# 181/181 [==============================] - 274s 2s/step - loss: 0.5010 - accuracy: 0.8256 - val_loss: 0.8122 - val_accuracy: 0.7657
# Epoch 22/50
# 181/181 [==============================] - 245s 1s/step - loss: 0.4876 - accuracy: 0.8284 - val_loss: 0.8102 - val_accuracy: 0.7657
# Epoch 23/50
# 181/181 [==============================] - 244s 1s/step - loss: 0.5155 - accuracy: 0.8239 - val_loss: 1.0328 - val_accuracy: 0.7097
# Epoch 24/50
# 181/181 [==============================] - 226s 1s/step - loss: 0.4914 - accuracy: 0.8343 - val_loss: 0.8540 - val_accuracy: 0.7657
# Epoch 25/50
# 181/181 [==============================] - 251s 1s/step - loss: 0.4851 - accuracy: 0.8322 - val_loss: 0.8591 - val_accuracy: 0.7505
# Epoch 26/50
# 181/181 [==============================] - 281s 2s/step - loss: 0.4655 - accuracy: 0.8334 - val_loss: 0.8566 - val_accuracy: 0.7581
# Epoch 27/50
# 181/181 [==============================] - 309s 2s/step - loss: 0.5078 - accuracy: 0.8258 - val_loss: 0.8017 - val_accuracy: 0.7685
# Epoch 28/50
# 181/181 [==============================] - 243s 1s/step - loss: 0.4732 - accuracy: 0.8374 - val_loss: 0.7945 - val_accuracy: 0.7782
# Epoch 29/50
# 181/181 [==============================] - 228s 1s/step - loss: 0.4672 - accuracy: 0.8353 - val_loss: 0.9712 - val_accuracy: 0.7319
# Epoch 30/50
# 181/181 [==============================] - 228s 1s/step - loss: 0.5185 - accuracy: 0.8256 - val_loss: 0.9189 - val_accuracy: 0.7491
# Epoch 31/50
# 181/181 [==============================] - 228s 1s/step - loss: 0.4705 - accuracy: 0.8405 - val_loss: 0.8698 - val_accuracy: 0.7429
# Epoch 32/50
# 181/181 [==============================] - 215s 1s/step - loss: 0.4866 - accuracy: 0.8311 - val_loss: 0.8693 - val_accuracy: 0.7464
# Epoch 33/50
# 181/181 [==============================] - 203s 1s/step - loss: 0.4591 - accuracy: 0.8403 - val_loss: 0.8344 - val_accuracy: 0.7574
# Epoch 34/50
# 181/181 [==============================] - 210s 1s/step - loss: 0.4634 - accuracy: 0.8382 - val_loss: 1.0180 - val_accuracy: 0.7070
# Epoch 35/50
# 181/181 [==============================] - 204s 1s/step - loss: 0.4547 - accuracy: 0.8412 - val_loss: 0.7997 - val_accuracy: 0.7816
# Epoch 36/50
# 181/181 [==============================] - 197s 1s/step - loss: 0.4459 - accuracy: 0.8470 - val_loss: 0.8202 - val_accuracy: 0.7795
# Epoch 37/50
# 181/181 [==============================] - 189s 1s/step - loss: 0.4753 - accuracy: 0.8379 - val_loss: 0.9202 - val_accuracy: 0.7512
# Epoch 38/50
# 181/181 [==============================] - 182s 999ms/step - loss: 0.4586 - accuracy: 0.8394 - val_loss: 0.8597 - val_accuracy: 0.7574
# Epoch 39/50
# 181/181 [==============================] - 177s 975ms/step - loss: 0.4567 - accuracy: 0.8393 - val_loss: 0.8090 - val_accuracy: 0.7678
# Epoch 40/50
# 181/181 [==============================] - 182s 1s/step - loss: 0.4422 - accuracy: 0.8453 - val_loss: 0.8334 - val_accuracy: 0.7595
# Epoch 41/50
# 181/181 [==============================] - 192s 1s/step - loss: 0.4551 - accuracy: 0.8410 - val_loss: 0.8170 - val_accuracy: 0.7816
# Epoch 42/50
# 181/181 [==============================] - 183s 1s/step - loss: 0.4371 - accuracy: 0.8526 - val_loss: 0.8264 - val_accuracy: 0.7837
# Epoch 43/50
# 181/181 [==============================] - 177s 975ms/step - loss: 0.4441 - accuracy: 0.8463 - val_loss: 1.0854 - val_accuracy: 0.7222
# Epoch 44/50
# 181/181 [==============================] - 179s 982ms/step - loss: 0.4521 - accuracy: 0.8462 - val_loss: 0.9559 - val_accuracy: 0.7457
# Epoch 45/50
# 181/181 [==============================] - 175s 960ms/step - loss: 0.4336 - accuracy: 0.8493 - val_loss: 0.8646 - val_accuracy: 0.7664
# Epoch 46/50
# 181/181 [==============================] - 230s 1s/step - loss: 0.4357 - accuracy: 0.8505 - val_loss: 0.8127 - val_accuracy: 0.7657
# Epoch 47/50
# 181/181 [==============================] - 201s 1s/step - loss: 0.4469 - accuracy: 0.8462 - val_loss: 0.8151 - val_accuracy: 0.7754
# Epoch 48/50
# 181/181 [==============================] - 194s 1s/step - loss: 0.4477 - accuracy: 0.8465 - val_loss: 0.7498 - val_accuracy: 0.7954
# Epoch 49/50
# 181/181 [==============================] - 248s 1s/step - loss: 0.4144 - accuracy: 0.8576 - val_loss: 0.9707 - val_accuracy: 0.7319
# Epoch 50/50
# 181/181 [==============================] - 246s 1s/step - loss: 0.4664 - accuracy: 0.8412 - val_loss: 0.8293 - val_accuracy: 0.7809

# %% [markdown]
# ####  Visualize the model results for 50 more epochs

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
